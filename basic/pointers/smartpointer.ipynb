# %% [markdown]
# ### Step 1: Why Smart Pointers?
# <pre>
#
# Problem with normal pointers:
#
#     You do new, but you may forget delete.
#
#     This causes memory leaks.
#
#     If you delete twice →  undefined behavior.
#
# Smart pointers = Automatic memory management.
# (Think of it like a nanny that automatically cleans the toys  after you're done playing.)
#
#
# </pre>
# # Types of Smart Pointer
#
# ![{3B9817CE-E13B-4D89-A429-C3ACFD168684}.png](attachment:{3B9817CE-E13B-4D89-A429-C3ACFD168684}.png)

# %% [markdown]
# ![{634B9627-1D3C-4B1D-ABE7-DAB4A6B5FF30}.png](attachment:{634B9627-1D3C-4B1D-ABE7-DAB4A6B5FF30}.png)

# %% [markdown]
# ![{CDE1C2AD-7227-49F1-B80D-0715E798C3BE}.png](attachment:{CDE1C2AD-7227-49F1-B80D-0715E798C3BE}.png)
# ![{C6371022-0E44-4E2B-94DC-1449FABAB4BA}.png](attachment:{C6371022-0E44-4E2B-94DC-1449FABAB4BA}.png)
